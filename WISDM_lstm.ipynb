# %% [markdown]
# <a href="https://colab.research.google.com/github/lisatwyw/data-gym/blob/master/WISDM_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overview #
#
# - This is a notebook prepared for you to try out classification tasks using time-series data acquired using accelerometers of iPhone's.
#
# - You'll get to:
#  - train a model based on neural networks
#  - learn about ```CoreML```
#
# - Post-demo exercise: try to replicate below using the [Actitracker dataset](http://www.cis.fordham.edu/wisdm/includes/datasets/latest/WISDM_at_latest.tar.gz)

# %% [markdown]
# # A) Mount Google drive #

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # B) Create subfolder ``wisdm`` in your ```opensource_datasets``` folder #

# %%
import os
if os.path.isdir('/content/drive/My Drive/Colab Notebooks/opensource_datasets/' )==False:
  try:
    ! mkdir '/content/drive/My Drive/Colab Notebooks/opensource_datasets/'
  except e as Exception:
    pass  

if os.path.isdir( '/content/drive/My Drive/Colab Notebooks/opensource_datasets/wisdm' )==False:
  try:
    ! mkdir '/content/drive/My Drive/Colab Notebooks/opensource_datasets/wisdm'
  except e as Exception:
    pass  
    
os.chdir('/content/drive/My Drive/Colab Notebooks/opensource_datasets/wisdm')

# %% [markdown]
# # C) Download from website and unzip contents ##

# %%
if os.path.isfile('wisdm.gz' )==False:
  try:
    ! wget -O wisdm.gz http://www.cis.fordham.edu/wisdm/includes/datasets/latest/WISDM_ar_latest.tar.gz
    ! tar -xf wisdm.gz
    print('done unzipping')
  except:
    pass

  ! ls

# %% [markdown]
# # D) Run the following demo code written by [Nils Ackermann](https://towardsdatascience.com/human-activity-recognition-har-tutorial-with-keras-and-core-ml-part-1-8c05e365dfa0?)#

# %%
import numpy as np
import pandas as pd

# https://towardsdatascience.com/human-activity-recognition-har-tutorial-with-keras-and-core-ml-part-1-8c05e365dfa0?

def read_data(file_path):

    column_names = ['user-id',
                    'activity',
                    'timestamp',
                    'x-axis',
                    'y-axis',
                    'z-axis']
    df = pd.read_csv(file_path,
                     header=None,
                     names=column_names)
    # Last column has a ";" character which must be removed ...
    df['z-axis'].replace(regex=True,
      inplace=True,
      to_replace=r';',
      value=r'')
    # ... and then this column must be transformed to float explicitly
    df['z-axis'] = df['z-axis'].apply(convert_to_float)
    # This is very important otherwise the model will not fit and loss
    # will show up as NAN
    df.dropna(axis=0, how='any', inplace=True)

    return df

def convert_to_float(x):

    try:
        return np.float(x)
    except:
        return np.nan
 
def show_basic_dataframe_info(dataframe):

    # Shape and how many rows and columns
    print('Number of columns in the dataframe: %i' % (dataframe.shape[1]))
    print('Number of rows in the dataframe: %i\n' % (dataframe.shape[0]))

# Load data set containing all the data from csv
df = read_data('WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt')

# %% [markdown]
# ## Examine the data ##

# %%
df.head(5)
# Out:
#    user-id activity       timestamp    x-axis     y-axis    z-axis
# 0       33  Jogging  49105962326000 -0.694638  12.680544  0.503953
# 1       33  Jogging  49106062271000  5.012288  11.264028  0.953424
# 2       33  Jogging  49106112167000  4.903325  10.882658 -0.081722
# 3       33  Jogging  49106222305000 -0.612916  18.496431  3.023717
# 4       33  Jogging  49106332290000 -1.184970  12.108489  7.205164

# %%
df.tail(25)
# Out:
#          user-id activity        timestamp  ...  y-axis  z-axis  ActivityEncoded
# 1098179       19  Sitting  131622331483000  ...    -1.3     2.3                2
# 1098180       19  Sitting  131622371522000  ...    -1.1     2.3                2
# 1098181       19  Sitting  131622451479000  ...    -1.1     2.3                2
# 1098182       19  Sitting  131622491487000  ...    -1.1     2.4                2
# 1098183       19  Sitting  131622531465000  ...    -1.1     2.4                2
# 1098184       19  Sitting  131622571443000  ...    -1.1     2.4                2
# 1098185       19  Sitting  131622611635000  ...    -1.2     2.5                2
# 1098186       19  Sitting  131622691469000  ...    -1.2     2.5                2
# 1098187       19  Sitting  131622731477000  ...    -1.3     2.5                2
# 1098188       19  Sitting  131622771486000  ...    -1.4     2.6                2
# 1098189       19  Sitting  131622851472000  ...    -1.5     2.6                2
# 1098190       19  Sitting  131622891511000  ...    -1.6     2.1                2
# 1098191       19  Sitting  131622931490000  ...    -1.5     2.3                2
# 1098192       19  Sitting  131622971498000  ...    -1.5     2.3                2
# 1098193       19  Sitting  131623051485000  ...    -1.2     2.3                2
# 1098194       19  Sitting  131623091524000  ...    -1.3     2.5                2
# 1098195       19  Sitting  131623131471000  ...    -1.3     2.4                2
# 1098196       19  Sitting  131623172578000  ...    -1.3     2.2                2
# 1098197       19  Sitting  131623251466000  ...    -1.4     1.9                2
# 1098198       19  Sitting  131623291475000  ...    -1.5     1.8                2
# 1098199       19  Sitting  131623331483000  ...    -1.6     1.7                2
# 1098200       19  Sitting  131623371431000  ...    -1.5     1.7                2
# 1098201       19  Sitting  131623411592000  ...    -1.4     1.7                2
# 1098202       19  Sitting  131623491487000  ...    -1.5     1.7                2
# 1098203       19  Sitting  131623531465000  ...    -1.3     1.6                2
#
# [25 rows x 7 columns]

# %%
ds=df['timestamp'][df['user-id']==19] 
dates2 = pd.to_datetime( ds )

dates2
# Out:
# 1052821   1970-01-02 12:00:12.111482
# 1052822   1970-01-02 12:00:12.151643
# 1052823   1970-01-02 12:00:12.191438
# 1052824   1970-01-02 12:00:12.231508
# 1052825   1970-01-02 12:00:12.311647
#                      ...
# 1098199   1970-01-02 12:33:43.331483
# 1098200   1970-01-02 12:33:43.371431
# 1098201   1970-01-02 12:33:43.411592
# 1098202   1970-01-02 12:33:43.491487
# 1098203   1970-01-02 12:33:43.531465
# Name: timestamp, Length: 45383, dtype: datetime64[ns]

# %%
xvalues=df['x-axis'][df['user-id']==19] 
yvalues=df['y-axis'][df['user-id']==19] 
zvalues=df['z-axis'][df['user-id']==19] 


H=24
W=12
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=( H, W ))
ax = fig.add_subplot(111, projection='3d',)

timepoints =20
ax.plot3D(xvalues[:timepoints],yvalues[:timepoints],zvalues[:timepoints], )
plt.title('In 3D')
# Out:
# Text(0.5, 0.92, 'In 3D')

# %%
H=W=10
plt.clf();
fig=plt.subplots(1,1, figsize=( H, W ));
plt.plot(xvalues[:timepoints], yvalues[:timepoints]);
plt.title('In 2D')
# Out:
# Text(0.5, 1.0, 'In 2D')

# %% [markdown]
# ## Prepare the output labels ##

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing

# Set some standard parameters upfront
pd.options.display.float_format = '{:.1f}'.format
sns.set() # Default seaborn look and feel


plt.style.use('ggplot')

# Same labels will be reused throughout the program
LABELS = ['Downstairs',
          'Jogging',
          'Sitting',
          'Standing',
          'Upstairs',
          'Walking']


# The number of steps within one time segment
TIME_PERIODS = 80

# The steps to take from one segment to the next; if this value is equal to TIME_PERIODS, then there is no overlap between the segments
STEP_DISTANCE = 40


# Define column name of the label vector
LABEL = 'ActivityEncoded'
# Transform the labels from String to Integer via LabelEncoder

le = preprocessing.LabelEncoder()
# Add a new column to the existing DataFrame with the encoded values
df[LABEL] = le.fit_transform(df['activity'].values.ravel())

num_classes = le.classes_.size
print(list(le.classes_))
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']

# %% [markdown]
# ## Split the dataset into training and test subsets ##

# %%
pd.options.mode.chained_assignment = None  # default='warn'

df_test = df[df['user-id'] > 28]
df_train = df[df['user-id'] <= 28]

# %% [markdown]
# ## Normalize the input data ##

# %%
df_train['x-axis'] = df_train['x-axis'] / df_train['x-axis'].max()
df_train['y-axis'] = df_train['y-axis'] / df_train['y-axis'].max()
df_train['z-axis'] = df_train['z-axis'] / df_train['z-axis'].max()

# Round numbers
df_train = df_train.round({'x-axis': 4, 'y-axis': 4, 'z-axis': 4})

# %%
import keras
print('keras version ', keras.__version__)
# Out:
# Using TensorFlow backend.
# keras version  2.3.1

# %% [markdown]
# ## Prepare the training dataset ##

# %%
from scipy import stats
from keras.utils import np_utils


def create_segments_and_labels(df, time_steps, step, label_name):

    # x, y, z acceleration as features
    N_FEATURES = 3
    # Number of steps to advance in each iteration (for me, it should always
    # be equal to the time_steps in order to have no overlap between segments)
    # step = time_steps
    segments = []
    labels = []
    for i in range(0, len(df) - time_steps, step):
        xs = df['x-axis'].values[i: i + time_steps]
        ys = df['y-axis'].values[i: i + time_steps]
        zs = df['z-axis'].values[i: i + time_steps]
        # Retrieve the most often used label in this segment
        label = stats.mode(df[label_name][i: i + time_steps])[0][0]
        segments.append([xs, ys, zs])
        labels.append(label)

    # Bring the segments into a better shape
    reshaped_segments = np.asarray(segments, dtype= np.float32).reshape(-1, time_steps, N_FEATURES)
    labels = np.asarray(labels)

    return reshaped_segments, labels

x_train, y_train = create_segments_and_labels(df_train,
                                              TIME_PERIODS,
                                              STEP_DISTANCE,
                                              LABEL)
# convert to float
x_train = x_train.astype('float32')
y_train = y_train.astype('float32')

# convert output labels using one-hot-encoding
y_train_hot = np_utils.to_categorical(y_train, num_classes)

# %%
y_train[::10]
# Out:
# array([5., 5., 5., ..., 2., 2., 2.], dtype=float32)

# %% [markdown]
# ## Plot 3 trajectories randomly drawn from the training set ##

# %%
s=1
timepoints =80
H=W=20;
fig = plt.figure(figsize=( H, W ))
ax = fig.add_subplot(111, projection='3d',)
lab='A sample of %s '% LABELS[ y_train[s].astype(int) ]
ax.plot3D(x_train[s,:timepoints,0],x_train[s,:timepoints,1],x_train[s,:timepoints,2], label=lab )

s=len(y_train)-1
lab='A sample of %s '% LABELS[ y_train[s].astype(int) ]
ax.plot3D(x_train[s,:timepoints,0],x_train[s,:timepoints,1],x_train[s,:timepoints,2], c='g', label=lab )
ax.legend( loc=2, prop={'size': 26} )

s=len(y_train)-100
lab='A sample of %s '% LABELS[ y_train[s].astype(int) ]
ax.plot3D(x_train[s,:timepoints,0],x_train[s,:timepoints,1],x_train[s,:timepoints,2], c='b', label=lab )
ax.legend( loc=2, prop={'size': 26} )

# %%
s=1
timepoints =80
H=W=20;
fig = plt.figure(figsize=( H, W ));
ax = fig.add_subplot(111, );
lab='A sample of %s '% LABELS[ y_train[s].astype(int) ];
ax.plot( x_train[s,:timepoints,1],x_train[s,:timepoints,2], label=lab );

s=len(y_train)-1
lab='A sample of %s '% LABELS[ y_train[s].astype(int) ];
ax.plot( x_train[s,:timepoints,1],x_train[s,:timepoints,2], c='g', label=lab );
ax.legend( loc=2, prop={'size': 26} );

s=len(y_train)-100
lab='A sample of %s '% LABELS[ y_train[s].astype(int) ];
ax.plot( x_train[s,:timepoints,1],x_train[s,:timepoints,2], c='b', label=lab );
ax.legend( loc=2, prop={'size': 26} );

ax.set_xlabel('Y dimension')
ax.set_ylabel('Z dimension')
# Out:
# Text(0, 0.5, 'Z dimension')

# %%
num_time_periods, num_sensors = x_train.shape[1], x_train.shape[2]
print( 'Input data:', x_train.shape, '\n3 time-series and 80 timepoints; total of', y_train.shape, 'samples' )

input_shape = (num_time_periods*num_sensors)

x_train = x_train.reshape(x_train.shape[0], input_shape)

print('After reshaping, x_train has shape', x_train.shape)
print('input_shape:', input_shape)
# Out:
# Input data: (20868, 80, 3)
# 3 time-series and 80 timepoints; total of (20868,) samples
# After reshaping, x_train has shape (20868, 240)
# input_shape: 240

# %% [markdown]
# ## Construct the model ##

# %%
import tensorflow as tf

model_m = tf.keras.models.Sequential()
# Remark: since coreml cannot accept vector shapes of complex shape like
# [80,3] this workaround is used in order to reshape the vector internally
# prior feeding it into the network
model_m.add(tf.keras.layers.Reshape((TIME_PERIODS, 3), input_shape=(input_shape,)))
model_m.add(tf.keras.layers.Dense(100, activation='relu'))
model_m.add(tf.keras.layers.Dense(90, activation='relu'))

model_m.add(tf.keras.layers.Dense(100, activation='relu'))
model_m.add(tf.keras.layers.Flatten())
model_m.add(tf.keras.layers.Dense(num_classes, activation='softmax'))
print(model_m.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 80, 3)             0
# _________________________________________________________________
# dense (Dense)                (None, 80, 100)           400
# _________________________________________________________________
# dense_1 (Dense)              (None, 80, 90)            9090
# _________________________________________________________________
# dense_2 (Dense)              (None, 80, 100)           9100
# _________________________________________________________________
# flatten (Flatten)            (None, 8000)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 48006
# =================================================================
# Total params: 66,596
# Trainable params: 66,596
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Train it! ##

# %%
callbacks_list = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath='best_model.{epoch:02d}-{val_loss:.2f}.h5',
        monitor='val_loss', save_best_only=True),
    tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=1)
]

model_m.compile(loss='categorical_crossentropy',
                optimizer='adam', metrics=['accuracy'])

# Hyper-parameters
BATCH_SIZE = 400
EPOCHS = 50

# Enable validation to use ModelCheckpoint and EarlyStopping callbacks.
history = model_m.fit(x_train,
                      y_train_hot,
                      batch_size=BATCH_SIZE,
                      epochs=EPOCHS,
                      callbacks=callbacks_list,
                      validation_split=0.2,
                      verbose=1)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 240) for input Tensor("reshape_input:0", shape=(None, 240), dtype=float32), but it was called on an input with incompatible shape (None, 80, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 240) for input Tensor("reshape_input:0", shape=(None, 240), dtype=float32), but it was called on an input with incompatible shape (None, 80, 3).
# 42/42 [==============================] - ETA: 0s - loss: 1.0827 - accuracy: 0.6479WARNING:tensorflow:Model was constructed with shape (None, 240) for input Tensor("reshape_input:0", shape=(None, 240), dtype=float32), but it was called on an input with incompatible shape (None, 80, 3).
# 42/42 [==============================] - 6s 144ms/step - loss: 1.0827 - accuracy: 0.6479 - val_loss: 0.7098 - val_accuracy: 0.8153
# Epoch 2/50
# 42/42 [==============================] - 6s 138ms/step - loss: 0.5943 - accuracy: 0.7901 - val_loss: 0.6490 - val_accuracy: 0.8083
# Epoch 3/50
# 42/42 [==============================] - 6s 139ms/step - loss: 0.5176 - accuracy: 0.8095 - val_loss: 0.6567 - val_accuracy: 0.8191
# Epoch 4/50
# 42/42 [==============================] - 6s 139ms/step - loss: 0.4837 - accuracy: 0.8259 - val_loss: 0.6541 - val_accuracy: 0.8138
# Epoch 5/50
# 42/42 [==============================] - 6s 137ms/step - loss: 0.4570 - accuracy: 0.8352 - val_loss: 0.6678 - val_accuracy: 0.8026
# Epoch 6/50
# 42/42 [==============================] - 6s 137ms/step - loss: 0.4349 - accuracy: 0.8435 - val_loss: 0.6529 - val_accuracy: 0.8297
# Epoch 7/50
# 42/42 [==============================] - 6s 137ms/step - loss: 0.4202 - accuracy: 0.8487 - val_loss: 0.7116 - val_accuracy: 0.7916
# Epoch 8/50
# 42/42 [==============================] - 6s 139ms/step - loss: 0.4051 - accuracy: 0.8540 - val_loss: 0.6925 - val_accuracy: 0.7683
# Epoch 9/50
# 42/42 [==============================] - 6s 139ms/step - loss: 0.3934 - accuracy: 0.8573 - val_loss: 0.6758 - val_accuracy: 0.7920
# Epoch 10/50
# 42/42 [==============================] - 6s 138ms/step - loss: 0.3811 - accuracy: 0.8591 - val_loss: 0.7627 - val_accuracy: 0.7190
# Epoch 11/50
# 42/42 [==============================] - 6s 140ms/step - loss: 0.3671 - accuracy: 0.8660 - val_loss: 0.7331 - val_accuracy: 0.7451
# Epoch 12/50
# 42/42 [==============================] - 6s 139ms/step - loss: 0.3540 - accuracy: 0.8710 - val_loss: 0.7563 - val_accuracy: 0.7283
# Epoch 13/50
# 42/42 [==============================] - 6s 140ms/step - loss: 0.3422 - accuracy: 0.8744 - val_loss: 0.7632 - val_accuracy: 0.7528
# Epoch 14/50
# 42/42 [==============================] - 6s 140ms/step - loss: 0.3268 - accuracy: 0.8819 - val_loss: 0.8267 - val_accuracy: 0.6902
# Epoch 15/50
# 42/42 [==============================] - 6s 140ms/step - loss: 0.3190 - accuracy: 0.8828 - val_loss: 0.7248 - val_accuracy: 0.7667
# Epoch 16/50
# 42/42 [==============================] - 6s 139ms/step - loss: 0.3076 - accuracy: 0.8865 - val_loss: 0.7458 - val_accuracy: 0.7554
# Epoch 17/50
# 42/42 [==============================] - 6s 140ms/step - loss: 0.2990 - accuracy: 0.8904 - val_loss: 0.8469 - val_accuracy: 0.7077
# Epoch 18/50
# 42/42 [==============================] - 6s 139ms/step - loss: 0.2966 - accuracy: 0.8910 - val_loss: 0.9061 - val_accuracy: 0.6756
# Epoch 19/50
# 42/42 [==============================] - 6s 139ms/step - loss: 0.2873 - accuracy: 0.8953 - val_loss: 0.8354 - val_accuracy: 0.7271
# Epoch 20/50
# 42/42 [==============================] - 6s 141ms/step - loss: 0.2757 - accuracy: 0.9010 - val_loss: 0.8725 - val_accuracy: 0.7022
# Epoch 21/50
# 42/42 [==============================] - 6s 139ms/step - loss: 0.2685 - accuracy: 0.9021 - val_loss: 0.8398 - val_accuracy: 0.7492
# Epoch 22/50
# 42/42 [==============================] - 6s 139ms/step - loss: 0.2646 - accuracy: 0.9013 - val_loss: 0.9447 - val_accuracy: 0.6854

# %% [markdown]
# ## Prepare the test subset ##

# %%
df_test['x-axis'] = df_test['x-axis'] / df_test['x-axis'].max()
df_test['y-axis'] = df_test['y-axis'] / df_test['y-axis'].max()
df_test['z-axis'] = df_test['z-axis'] / df_test['z-axis'].max()

# Round numbers
df_test = df_test.round({'x-axis': 4, 'y-axis': 4, 'z-axis': 4})

x_test, y_test = create_segments_and_labels( df_test,
                                              TIME_PERIODS,
                                              STEP_DISTANCE,
                                              LABEL)
# convert to float
x_test = x_test.astype('float32')
y_test = y_test.astype('float32')

# convert output labels using one-hot-encoding
y_test_hot = np_utils.to_categorical(y_test, num_classes)

# %%
y_test.shape
# Out:
# (6584,)

# %% [markdown]
# ## Evaluate the model on the test set and report results with a confusion matrix ##

# %%
plt.figure(figsize=(6, 4))
plt.plot(history.history['accuracy'], 'r', label='Accuracy of training data')
plt.plot(history.history['val_accuracy'], 'b', label='Accuracy of validation data')
plt.plot(history.history['loss'], 'r--', label='Loss of training data')
plt.plot(history.history['val_loss'], 'b--', label='Loss of validation data')
plt.title('Model Accuracy and Loss')
plt.ylabel('Accuracy and Loss')
plt.xlabel('Training Epoch')
plt.ylim(0)
plt.legend()
plt.show()

# Print confusion matrix for training data
y_pred_train = model_m.predict(x_train)
# Take the class with the highest probability from the train predictions
max_y_pred_train = np.argmax(y_pred_train, axis=1)


print(classification_report(y_train, max_y_pred_train))


x_test = x_test.reshape(x_test.shape[0], input_shape)

y_pred_test = model_m.predict(x_test)

# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)


import seaborn as sns  # ! pip install seaborn
import matplotlib.pyplot as plt
from sklearn import metrics

def show_confusion_matrix(validations, predictions, LABELS ):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 4))
    sns.heatmap(matrix,
                cmap='coolwarm',
                linecolor='white',
                linewidths=1,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# y_test, max_y_pred_test are (nSamples,1), LABELS is a list of the classes, indexed from 0 up to num_classes-1
show_confusion_matrix(y_test, max_y_pred_test, LABELS )

print(classification_report(y_test, max_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.67      0.57      1864
#          1.0       0.97      0.98      0.98      6567
#          2.0       0.99      0.99      0.99      1050
#          3.0       0.99      0.99      0.99       833
#          4.0       0.67      0.54      0.60      2342
#          5.0       0.89      0.86      0.88      8212
#
#     accuracy                           0.86     20868
#    macro avg       0.84      0.84      0.83     20868
# weighted avg       0.87      0.86      0.86     20868
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.45      0.47       650
#          1.0       0.77      0.94      0.85      1990
#          2.0       0.78      1.00      0.88       452
#          3.0       0.94      0.66      0.78       370
#          4.0       0.50      0.37      0.43       725
#          5.0       0.77      0.69      0.73      2397
#
#     accuracy                           0.73      6584
#    macro avg       0.71      0.69      0.69      6584
# weighted avg       0.72      0.73      0.72      6584

# %% [markdown]
# # E) Change some hyperparameters and examine effect of the changes #

# %%
callbacks_list = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath='best_model.{epoch:02d}-{val_loss:.2f}.h5',
        monitor='val_loss', save_best_only=True),
    tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=2) # <-- changed
]

model_m.compile(loss='categorical_crossentropy',
                optimizer='adam', metrics=['accuracy'])

# Hyper-parameters
BATCH_SIZE = 128 # <-- changed
EPOCHS = 100  # <-- changed

# Enable validation to use ModelCheckpoint and EarlyStopping callbacks.
history = model_m.fit(x_train,
                      y_train_hot,
                      batch_size=BATCH_SIZE,
                      epochs=EPOCHS,
                      initial_epoch=0,                      
                      callbacks=callbacks_list,
                      validation_split=0.2,
                      verbose=1)

# %%
from sklearn.metrics import classification_report
 
def draw_plot():
  plt.figure(figsize=(6, 4))
  plt.plot(history.history['accuracy'], 'r', label='Accuracy of training data')
  plt.plot(history.history['val_accuracy'], 'b', label='Accuracy of validation data')
  plt.plot(history.history['loss'], 'r--', label='Loss of training data')
  plt.plot(history.history['val_loss'], 'b--', label='Loss of validation data')
  plt.title('Model Accuracy and Loss')
  plt.ylabel('Accuracy and Loss')
  plt.xlabel('Training Epoch')
  plt.ylim(0)
  plt.legend()
  plt.show()

  # Print confusion matrix for training data
  y_pred_train = model_m.predict(x_train)
  # Take the class with the highest probability from the train predictions
  max_y_pred_train = np.argmax(y_pred_train, axis=1)

  print(classification_report(y_train, max_y_pred_train))

draw_plot()

x_test = x_test.reshape(x_test.shape[0], input_shape)

y_pred_test = model_m.predict(x_test)

# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)


import seaborn as sns  # ! pip install seaborn
import matplotlib.pyplot as plt
from sklearn import metrics

def show_confusion_matrix(validations, predictions, LABELS ):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 4))
    sns.heatmap(matrix,
                cmap='coolwarm',
                linecolor='white',
                linewidths=1,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# y_test, max_y_pred_test are (nSamples,1), LABELS is a list of the classes, indexed from 0 up to num_classes-1
show_confusion_matrix(y_test, max_y_pred_test, LABELS )

print(classification_report(y_test, max_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.67      0.57      1864
#          1.0       0.97      0.98      0.98      6567
#          2.0       0.99      0.99      0.99      1050
#          3.0       0.99      0.99      0.99       833
#          4.0       0.67      0.54      0.60      2342
#          5.0       0.89      0.86      0.88      8212
#
#     accuracy                           0.86     20868
#    macro avg       0.84      0.84      0.83     20868
# weighted avg       0.87      0.86      0.86     20868
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.45      0.47       650
#          1.0       0.77      0.94      0.85      1990
#          2.0       0.78      1.00      0.88       452
#          3.0       0.94      0.66      0.78       370
#          4.0       0.50      0.37      0.43       725
#          5.0       0.77      0.69      0.73      2397
#
#     accuracy                           0.73      6584
#    macro avg       0.71      0.69      0.69      6584
# weighted avg       0.72      0.73      0.72      6584

# %% [markdown]
# # F) Install library ```coreML``` if not already available #
#
# ...updating to module 3.1 per suggestions on [CoreML support](https://github.com/apple/coremltools/issues/446)

# %%
try:
  import coremltools
except:
  ! pip install coremltools==3.1  
  import coremltools

#dir( coremltools.converters.tensorflow.convert )
# Out:
# Collecting coremltools==3.1
#   Downloading https://files.pythonhosted.org/packages/af/f8/ac6940600864b08476fee09583b7c66e2fcfe70ccafeb696710103c4a31b/coremltools-3.1-cp36-none-manylinux1_x86_64.whl (3.4MB)
#      |████████████████████████████████| 3.4MB 2.8MB/s
# Requirement already satisfied: protobuf>=3.1.0 in /usr/local/lib/python3.6/dist-packages (from coremltools==3.1) (3.10.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from coremltools==3.1) (1.18.4)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from coremltools==3.1) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.1.0->coremltools==3.1) (46.1.3)
# Installing collected packages: coremltools
# Successfully installed coremltools-3.1
# WARNING:root:TensorFlow version 2.2.0-rc4 detected. Last version known to be fully compatible is 1.14.0 .
# WARNING:root:Keras version 2.3.1 detected. Last version known to be fully compatible of Keras is 2.2.4 .
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# # G) Export to CoreML file #

# %%
coreml_model = coremltools.converters.tensorflow.convert(model_m,
                                                    input_names=['acceleration'],
                                                    output_names=['output'],
                                                    class_labels=LABELS)
if 1:
  print(coreml_model)
  coreml_model.author = 'Nils Ackermann'
  coreml_model.license = 'N/A'
  coreml_model.short_description = 'Activity based recognition based on WISDM dataset'
  coreml_model.output_description['output'] = 'Probability of each activity'
  coreml_model.output_description['classLabel'] = 'Labels of activity'

  #coreml_model.save('HARClassifier.mlmodel')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-7c34a26e4a78> in <module>()
#       2                                                     input_names=['acceleration'],
#       3                                                     output_names=['output'],
# ----> 4                                                     class_labels=LABELS)
#       5 if 1:
#       6   print(coreml_model)
#
# /usr/local/lib/python3.6/dist-packages/coremltools/converters/tensorflow/_tf_converter.py in convert(filename, inputs, outputs, image_input_names, is_bgr, red_bias, green_bias, blue_bias, gray_bias, image_scale, class_labels, predicted_feature_name, predicted_probabilities_output, add_custom_layers, custom_conversion_functions, custom_shape_functions, **kwargs)
#      62         filename = _graph_def_from_concrete_function(filename)
#      63     else:
# ---> 64         raise ValueError(invalid_filename_message)
#      65
#      66     # convert from TensorFlow to SSA IR
#
# ValueError: invalid input tf_model_path: <tensorflow.python.keras.engine.sequential.Sequential object at 0x7fd3e20bb278>!
# Supported tf_model_path input format includes:
# - Path to TensorFlow frozen graph (.pb) file
# - Path to TensorFlow tf.keras model (.h5) file
# - Path to TensorFlow SavedModel directory
# - List of TensorFlow concrete functions

# %%
'''
model = Sequential()
model.add(LSTM(NU, input_shape = input_shape, return_sequences = True, kernel_initializer = 'uniform', activation ='relu'))
model.add(LSTM(NU, kernel_initializer = 'uniform', return_sequences = False ))
model.add(Dense(64, activation = 'relu'))            
model.add(Dense(1, activation = 'linear'))
''';
callbacks_list = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath='best_model.{epoch:02d}-{val_loss:.2f}.h5',
        monitor='val_loss', save_best_only=True),
    tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=10) # <-- changed
]


model_m2 = tf.keras.models.Sequential()
model_m2.add(tf.keras.layers.Reshape((TIME_PERIODS, 3), input_shape=(input_shape,)))
model_m2.add(tf.keras.layers.LSTM(100, return_sequences = True, kernel_initializer = 'uniform', activation ='relu' ))
model_m2.add(tf.keras.layers.LSTM(90, kernel_initializer = 'uniform', return_sequences = False  ))
model_m2.add(tf.keras.layers.Dense(100, activation='relu'))
model_m2.add(tf.keras.layers.Flatten())
model_m2.add(tf.keras.layers.Dense(num_classes, activation='softmax'))

print(model_m2.summary())

model_m2.compile(loss='categorical_crossentropy',
                optimizer='nadam', metrics=['accuracy'])

# Hyper-parameters
BATCH_SIZE = 128 # <-- changed
EPOCHS = 100  # <-- changed

# Enable validation to use ModelCheckpoint and EarlyStopping callbacks.
history = model_m2.fit(x_train,
                      y_train_hot,
                      batch_size=BATCH_SIZE,
                      epochs=EPOCHS,
                      initial_epoch=0,                      
                      callbacks=callbacks_list,
                      validation_split=0.2,
                      verbose=1)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_4 (Reshape)          (None, 80, 3)             0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 80, 100)           41600
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 90)                68760
# _________________________________________________________________
# dense_10 (Dense)             (None, 100)               9100
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 100)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 6)                 606
# =================================================================
# Total params: 120,066
# Trainable params: 120,066
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 240) for input Tensor("reshape_4_input:0", shape=(None, 240), dtype=float32), but it was called on an input with incompatible shape (None, 80, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 240) for input Tensor("reshape_4_input:0", shape=(None, 240), dtype=float32), but it was called on an input with incompatible shape (None, 80, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 240) for input Tensor("reshape_4_input:0", shape=(None, 240), dtype=float32), but it was called on an input with incompatible shape (None, 80, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 240) for input Tensor("reshape_4_input:0", shape=(None, 240), dtype=float32), but it was called on an input with incompatible shape (None, 80, 3).
# 131/131 [==============================] - ETA: 0s - loss: 1.1180 - accuracy: 0.5897WARNING:tensorflow:Model was constructed with shape (None, 240) for input Tensor("reshape_4_input:0", shape=(None, 240), dtype=float32), but it was called on an input with incompatible shape (None, 80, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 240) for input Tensor("reshape_4_input:0", shape=(None, 240), dtype=float32), but it was called on an input with incompatible shape (None, 80, 3).
# 131/131 [==============================] - 49s 374ms/step - loss: 1.1180 - accuracy: 0.5897 - val_loss: 0.8740 - val_accuracy: 0.7381
# Epoch 2/100
# 131/131 [==============================] - 48s 370ms/step - loss: 0.6884 - accuracy: 0.7478 - val_loss: 0.7301 - val_accuracy: 0.7453
# Epoch 3/100
# 131/131 [==============================] - 48s 370ms/step - loss: 0.6514 - accuracy: 0.7599 - val_loss: 0.6119 - val_accuracy: 0.8148
# Epoch 4/100
# 131/131 [==============================] - 48s 369ms/step - loss: 0.6062 - accuracy: 0.7743 - val_loss: 0.6351 - val_accuracy: 0.8023
# Epoch 5/100
# 131/131 [==============================] - 49s 371ms/step - loss: 0.5396 - accuracy: 0.7996 - val_loss: 0.5709 - val_accuracy: 0.8347
# Epoch 6/100
# 131/131 [==============================] - 48s 366ms/step - loss: 0.4956 - accuracy: 0.8149 - val_loss: 2.5146 - val_accuracy: 0.1864
# Epoch 7/100
# 131/131 [==============================] - 49s 371ms/step - loss: 0.6208 - accuracy: 0.7792 - val_loss: 0.5644 - val_accuracy: 0.8380
# Epoch 8/100
# 131/131 [==============================] - 48s 368ms/step - loss: 0.4602 - accuracy: 0.8289 - val_loss: 0.5697 - val_accuracy: 0.8263
# Epoch 9/100
# 131/131 [==============================] - 48s 370ms/step - loss: 0.4222 - accuracy: 0.8398 - val_loss: 0.6094 - val_accuracy: 0.8232
# Epoch 10/100
# 131/131 [==============================] - 48s 368ms/step - loss: 0.4084 - accuracy: 0.8432 - val_loss: 0.5695 - val_accuracy: 0.8275
# Epoch 11/100
# 131/131 [==============================] - 48s 367ms/step - loss: 0.3850 - accuracy: 0.8535 - val_loss: 0.6520 - val_accuracy: 0.7482
# Epoch 12/100
# 131/131 [==============================] - 49s 371ms/step - loss: 0.3836 - accuracy: 0.8526 - val_loss: 0.6418 - val_accuracy: 0.7714
# Epoch 13/100
# 131/131 [==============================] - 48s 366ms/step - loss: 0.3550 - accuracy: 0.8664 - val_loss: 0.6299 - val_accuracy: 0.8230
# Epoch 14/100
# 131/131 [==============================] - 48s 368ms/step - loss: 0.3545 - accuracy: 0.8689 - val_loss: 0.7516 - val_accuracy: 0.7187
# Epoch 15/100
# 131/131 [==============================] - 48s 369ms/step - loss: 0
100
# 131/131 [==============================] - 48s 369ms/step - loss: 0.0265 - accuracy: 0.9918 - val_loss: 1.2203 - val_accuracy: 0.7310
# Epoch 87/100
# 131/131 [==============================] - 48s 368ms/step - loss: 0.0255 - accuracy: 0.9913 - val_loss: 1.0869 - val_accuracy: 0.7726
# Epoch 88/100
# 131/131 [==============================] - 49s 371ms/step - loss: 0.0159 - accuracy: 0.9947 - val_loss: 1.2850 - val_accuracy: 0.7597
# Epoch 89/100
# 131/131 [==============================] - 48s 368ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 1.1364 - val_accuracy: 0.7719
# Epoch 90/100
# 131/131 [==============================] - 48s 370ms/step - loss: 0.0422 - accuracy: 0.9864 - val_loss: 1.2866 - val_accuracy: 0.7489
# Epoch 91/100
# 131/131 [==============================] - 49s 371ms/step - loss: 0.0342 - accuracy: 0.9895 - val_loss: 1.3638 - val_accuracy: 0.7645
# Epoch 92/100
# 131/131 [==============================] - 48s 369ms/step - loss: 0.0188 - accuracy: 0.9940 - val_loss: 1.4512 - val_accuracy: 0.7247
# Epoch 93/100
# 131/131 [==============================] - 48s 370ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 1.2472 - val_accuracy: 0.7841
# Epoch 94/100
# 131/131 [==============================] - 49s 371ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 1.2791 - val_accuracy: 0.7906
# Epoch 95/100
# 131/131 [==============================] - 49s 372ms/step - loss: 0.0332 - accuracy: 0.9895 - val_loss: 1.2663 - val_accuracy: 0.7391
# Epoch 96/100
# 131/131 [==============================] - 49s 371ms/step - loss: 0.0171 - accuracy: 0.9945 - val_loss: 1.2478 - val_accuracy: 0.7322
# Epoch 97/100
# 131/131 [==============================] - 48s 369ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.9537 - val_accuracy: 0.8055
# Epoch 98/100
# 131/131 [==============================] - 49s 372ms/step - loss: 0.0094 - accuracy: 0.9981 - val_loss: 1.4734 - val_accuracy: 0.7664
# Epoch 99/100
# 131/131 [==============================] - 49s 370ms/step - loss: 0.0072 - accuracy: 0.9983 - val_loss: 1.5524 - val_accuracy: 0.7650
# Epoch 100/100
# 131/131 [==============================] - 49s 372ms/step - loss: 0.0163 - accuracy: 0.9938 - val_loss: 1.4334 - val_accuracy: 0.7413

# %%
from sklearn.metrics import classification_report
 
def draw_plot( a_model ):
  plt.figure(figsize=(6, 4))
  plt.plot(history.history['accuracy'], 'r', label='Accuracy of training data')
  plt.plot(history.history['val_accuracy'], 'b', label='Accuracy of validation data')
  plt.plot(history.history['loss'], 'r--', label='Loss of training data')
  plt.plot(history.history['val_loss'], 'b--', label='Loss of validation data')
  plt.title('Model Accuracy and Loss')
  plt.ylabel('Accuracy and Loss')
  plt.xlabel('Training Epoch')
  plt.ylim(0)
  plt.legend()
  plt.show()

  # Print confusion matrix for training data
  y_pred_train = a_model.predict(x_train)
  # Take the class with the highest probability from the train predictions
  max_y_pred_train = np.argmax(y_pred_train, axis=1)

  print(classification_report(y_train, max_y_pred_train))

draw_plot( model_m2 )


x_test = x_test.reshape(x_test.shape[0], input_shape)
y_pred_test = model_m2.predict(x_test)

# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)

show_confusion_matrix(y_test, max_y_pred_test, LABELS )

print(classification_report(y_test, max_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.89      0.86      1864
#          1.0       0.98      0.96      0.97      6567
#          2.0       1.00      0.99      0.99      1050
#          3.0       0.99      1.00      0.99       833
#          4.0       0.82      0.91      0.86      2342
#          5.0       0.97      0.94      0.95      8212
#
#     accuracy                           0.94     20868
#    macro avg       0.93      0.95      0.94     20868
# weighted avg       0.95      0.94      0.94     20868
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.65      0.72       650
#          1.0       0.82      0.94      0.88      1990
#          2.0       0.96      1.00      0.98       452
#          3.0       1.00      0.94      0.97       370
#          4.0       0.68      0.70      0.69       725
#          5.0       0.92      0.84      0.88      2397
#
#     accuracy                           0.86      6584
#    macro avg       0.86      0.85      0.85      6584
# weighted avg       0.86      0.86      0.85      6584

# %%
! ls -lstr
# Out:
# total 63044
#     4 drwx------ 2 root root     4096 Dec  2  2012  WISDM_ar_v1.1
#   840 -rw------- 1 root root   859512 Mar 24 20:28  best_model.04-0.61.h5
#   270 -rw------- 1 root root   275546 Mar 24 20:55  HARClassifier.mlmodel
# 11138 -rw------- 1 root root 11404612 Apr  7 17:51  wisdm.gz
#   844 -rw------- 1 root root   864136 Apr  7 17:55  best_model.01-1.25.h5
#   844 -rw------- 1 root root   864136 Apr  7 17:55  best_model.02-1.10.h5
#   844 -rw------- 1 root root   864136 Apr  7 17:55  best_model.03-0.94.h5
#   844 -rw------- 1 root root   864136 Apr  7 17:55  best_model.04-0.93.h5
#   844 -rw------- 1 root root   864136 Apr  7 17:56  best_model.05-0.89.h5
#   844 -rw------- 1 root root   864136 Apr  7 17:56  best_model.06-0.88.h5
#   844 -rw------- 1 root root   864136 Apr  7 17:56  best_model.09-0.87.h5
#   844 -rw------- 1 root root   864136 Apr  7 17:56  best_model.10-0.86.h5
#   844 -rw------- 1 root root   864136 Apr  7 17:57  best_model.02-0.64.h5
#   844 -rw------- 1 root root   864136 Apr  7 17:57  best_model.03-0.63.h5
#   726 -rw------- 1 root root   743080 Apr  7 18:51  best_model.01-1.34.h5
#   726 -rw------- 1 root root   743080 Apr  7 18:51  best_model.02-1.21.h5
#   726 -rw------- 1 root root   743080 Apr  7 18:51  best_model.03-1.03.h5
#   726 -rw------- 1 root root   743080 Apr  7 18:51  best_model.04-0.94.h5
#   726 -rw------- 1 root root   743080 Apr  7 18:51  best_model.08-0.91.h5
#   726 -rw------- 1 root root   743080 Apr  7 18:51  best_model.10-0.90.h5
#   726 -rw------- 1 root root   743080 Apr  7 19:52  best_model.01-0.92.h5
#   726 -rw------- 1 root root   743080 Apr  7 19:52  best_model.02-0.88.h5
#   774 -rw------- 1 root root   792448 Apr  7 19:58  best_model.01-1.33.h5
#   774 -rw------- 1 root root   792448 Apr  7 19:58  best_model.02-1.04.h5
#   774 -rw------- 1 root root   792448 Apr  7 19:58  best_model.03-1.02.h5
#   845 -rw------- 1 root root   864448 Apr  7 20:11  best_model.01-1.37.h5
#   845 -rw------- 1 root root   864448 Apr  7 20:11  best_model.02-1.09.h5
#   845 -rw------- 1 root root   864448 Apr  7 20:11  best_model.03-1.05.h5
#   845 -rw------- 1 root root   864448 Apr  7 20:15  best_model.01-0.86.h5
#   845 -rw------- 1 root root   864448 Apr  7 20:15  best_model.02-0.79.h5
#   844 -rw------- 1 root root   864136 Apr  7 20:18  best_model.01-1.46.h5
#   844 -rw------- 1 root root   864136 Apr  7 20:19  best_model.04-1.32.h5
#   844 -rw------- 1 root root   864136 Apr  7 20:19  best_model.06-1.16.h5
#   844 -rw------- 1 root root   864136 Apr  7 20:22  best_model.01-1.63.h5
#   844 -rw------- 1 root root   864136 Apr  7 20:23  best_model.02-1.50.h5
#   844 -rw------- 1 root root   864136 Apr  7 20:58  best_model.01-0.75.h5
#   844 -rw------- 1 root root   864136 Apr  7 20:59  best_model.06-0.66.h5
#   844 -rw------- 1 root root   864136 Apr  7 21:00  best_model.01-0.78.h5
#   845 -rw------- 1 root root   864448 Apr  7 21:01 'mid:  1_best.h5'
#   845 -rw------- 1 root root   864448 Apr  7 22:15  mid001.h5
#   821 -rw------- 1 root root   840136 Apr  7 22:22  best_model.01-0.73.h5
#   821 -rw------- 1 root root   840136 Apr  7 22:22  best_model.02-0.66.h5
#   821 -rw------- 1 root root   840136 Apr  7 22:22  best_model.03-0.65.h5
#   821 -rw------- 1 root root   840136 Apr  7 22:22  best_model.04-0.64.h5
#   892 -rw------- 1 root root   912552 Apr  7 23:16  mid101_best.h5
#   821 -rw------- 1 root root   840136 Apr 14 20:56  best_model.01-0.76.h5
#   821 -rw------- 1 root root   840136 Apr 19 00:34  best_model.01-0.74.h5
#   821 -rw------- 1 root root   840136 Apr 19 00:34  best_model.02-0.67.h5
#   821 -rw------- 1 root root   840136 Apr 19 00:34  best_model.03-0.66.h5
#   821 -rw------- 1 root root   840136 Apr 19 00:34  best_model.04-0.63.h5
#   821 -rw------- 1 root root   840136 May  8 22:01  best_model.01-0.71.h5
#   821 -rw------- 1 root root   840136 May  8 22:01  best_model.02-0.65.h5
#  1455 -rw------- 1 root root  1489912 May  8 22:30  best_model.01-0.65.h5
#  1455 -rw------- 1 root root  1489912 May  8 22:31  best_model.03-0.60.h5
#  1455 -rw------- 1 root root  1489912 May  8 22:33  best_model.05-0.58.h5
#  1456 -rw------- 1 root root  1490256 May  8 23:03  best_model.01-0.87.h5
#  1456 -rw------- 1 root root  1490256 May  8 23:03  best_model.02-0.73.h5
#  1456 -rw------- 1 root root  1490256 May  8 23:04  best_model.03-0.61.h5
#  1456 -rw------- 1 root root  1490256 May  8 23:06  best_model.05-0.57.h5
#  1456 -rw------- 1 root root  1490256 May  8 23:07  best_model.07-0.56.h5

# %%
model_m2.load_weights('best_model.07-0.56.h5')

x_test = x_test.reshape(x_test.shape[0], input_shape)
y_pred_test = model_m2.predict(x_test)

# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)

show_confusion_matrix(y_test, max_y_pred_test, LABELS )

print(classification_report(y_test, max_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.14      0.23      1864
#          1.0       0.94      0.98      0.96      6567
#          2.0       0.99      0.92      0.96      1050
#          3.0       0.91      0.99      0.95       833
#          4.0       0.53      0.34      0.41      2342
#          5.0       0.78      0.96      0.86      8212
#
#     accuracy                           0.82     20868
#    macro avg       0.79      0.72      0.73     20868
# weighted avg       0.80      0.82      0.79     20868
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.09      0.14       650
#          1.0       0.83      0.95      0.89      1990
#          2.0       1.00      0.91      0.95       452
#          3.0       0.85      0.98      0.91       370
#          4.0       0.40      0.30      0.34       725
#          5.0       0.71      0.81      0.76      2397
#
#     accuracy                           0.74      6584
#    macro avg       0.69      0.67      0.67      6584
# weighted avg       0.70      0.74      0.71      6584

# %% [markdown]
# <a href="https://colab.research.google.com/github/lisatwyw/data-gym/blob/master/PTB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Oveview #
#
# Getting started to data analyses using data from [PTB]()

# %% [markdown]
# ## A) Mount and create subfolder ##

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False )

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
if os.path.isdir('/content/drive/My Drive/Colab Notebooks/opensource_datasets/' )==False:
  try:
    ! mkdir '/content/drive/My Drive/Colab Notebooks/opensource_datasets/'
  except e as Exception:
    pass  

if os.path.isdir( '/content/drive/My Drive/Colab Notebooks/opensource_datasets/PTB' )==False:
  try:
    ! mkdir '/content/drive/My Drive/Colab Notebooks/opensource_datasets/PTB'
  except e as Exception:
    pass  
    
os.chdir('/content/drive/My Drive/Colab Notebooks/opensource_datasets/PTB')

# %% [markdown]
# ## B) Download csv  ##

# %%
! wget -O ptbxl_database.csv https://physionet.org/files/ptb-xl/1.0.1/ptbxl_database.csv?download
! wget -O scp_statements.csv https://physionet.org/files/ptb-xl/1.0.1/scp_statements.csv?download
# Out:
# --2020-05-07 20:49:18--  https://physionet.org/files/ptb-xl/1.0.1/ptbxl_database.csv?download
# Resolving physionet.org (physionet.org)... 18.13.52.205
# Connecting to physionet.org (physionet.org)|18.13.52.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6602796 (6.3M) [text/plain]
# Saving to: ‘ptbxl_database.csv’
#
# ptbxl_database.csv  100%[===================>]   6.30M  4.39MB/s    in 1.4s
#
# 2020-05-07 20:49:21 (4.39 MB/s) - ‘ptbxl_database.csv’ saved [6602796/6602796]

# %%
! ls
# Out:
# ptbxl_database.csv  scp_statements.csv

# %%
import pandas as pd
Y = pd.read_csv('ptbxl_database.csv' )
#Y.scp_codes = Y.scp_codes.apply(lambda x: ast.literal_eval(x))
Y.head(20)
# Out:
#     ecg_id  patient_id  ...                filename_lr                filename_hr
# 0        1     15709.0  ...  records100/00000/00001_lr  records500/00000/00001_hr
# 1        2     13243.0  ...  records100/00000/00002_lr  records500/00000/00002_hr
# 2        3     20372.0  ...  records100/00000/00003_lr  records500/00000/00003_hr
# 3        4     17014.0  ...  records100/00000/00004_lr  records500/00000/00004_hr
# 4        5     17448.0  ...  records100/00000/00005_lr  records500/00000/00005_hr
# 5        6     19005.0  ...  records100/00000/00006_lr  records500/00000/00006_hr
# 6        7     16193.0  ...  records100/00000/00007_lr  records500/00000/00007_hr
# 7        8     11275.0  ...  records100/00000/00008_lr  records500/00000/00008_hr
# 8        9     18792.0  ...  records100/00000/00009_lr  records500/00000/00009_hr
# 9       10      9456.0  ...  records100/00000/00010_lr  records500/00000/00010_hr
# ...

# %%
scp = pd.read_csv('scp_statements.csv')
scp.head(20)
# Out:
#    Unnamed: 0  ...          DICOM Code
# 0         NDT  ...                 NaN
# 1        NST_  ...                 NaN
# 2         DIG  ...                 NaN
# 3       LNGQT  ...                 NaN
# 4        NORM  ...             F-000B7
# 5         IMI  ...                 NaN
# 6        ASMI  ...                 NaN
# 7         LVH  ...                 NaN
# 8        LAFB  ...            D3-33140
# 9        ISC_  ...                 NaN
# 10      IRBBB  ...            D3-33112
# 11       1AVB  ...                 NaN
# 12       IVCD  ...            D3-33000
# 13      ISCAL  ...                 NaN
# 14      CRBBB  ...            D3-33110
# 15      CLBBB  ...  D3-33120 or 122752
# 16       ILMI  ...                 NaN
# 17    LAO/LAE  ...                 NaN
# 18        AMI  ...                 NaN
# 19       ALMI  ...                 NaN
#
# [20 rows x 13 columns]

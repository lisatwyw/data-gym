# %% [markdown]
# <a href="https://colab.research.google.com/github/lisatwyw/data-gym/blob/master/Fitbit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Oveview #
#
# Getting started to data analyses using data from...

# %% [markdown]
# ## A) Mount ##

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=False)

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## B) Download the [```Fitbit```](https://github.com/UMN-RXInformatics/virtual-study-coordinator/blob/master/analysis/graph_fitbit_study.py) dataset ##
#
# Details:
#
# - 7-day measurements from 18 participants
# - each responded to Ecologic Momemntary Assessment (EMA) surveys (every two hours) sent to them via Twilio text messaging
# - each responded to cognitive tasks over the telephone using Twilio interactive voice response system.

# %%
! wget -O fitbit.csv.gz https://github.com/UMN-RXInformatics/virtual-study-coordinator/raw/master/data/alldata.csv.gz
! gunzip -k fitbit.csv.gz 
! ls
# Out:
# --2020-05-08 01:55:02--  https://github.com/UMN-RXInformatics/virtual-study-coordinator/raw/master/data/alldata.csv.gz
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/UMN-RXInformatics/virtual-study-coordinator/master/data/alldata.csv.gz [following]
# --2020-05-08 01:55:02--  https://raw.githubusercontent.com/UMN-RXInformatics/virtual-study-coordinator/master/data/alldata.csv.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33073967 (32M) [application/octet-stream]
# Saving to: ‘fitbit.csv.gz’
#
# fitbit.csv.gz       100%[===================>]  31.54M   168MB/s    in 0.2s
#
# 2020-05-08 01:55:03 (168 MB/s) - ‘fitbit.csv.gz’ saved [33073967/33073967]
#
# fitbit.csv  fitbit.csv.gz  gdrive  sample_data

# %%
import pandas as pd
fitbit = pd.read_csv('fitbit.csv')

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

from IPython.display import Javascript
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 14821})'''))

fitbit.head(61)
# Out:
#               Timestamp  Subject    HR  Steps  Elevation  EMA_period_type  \
# 0   2017-12-14 08:57:11        6  70.0      0        0.0              3.0
# 1   2017-12-14 08:57:12        6   NaN      0        0.0              3.0
# 2   2017-12-14 08:57:13        6   NaN      0        0.0              3.0
# 3   2017-12-14 08:57:14        6   NaN      0        0.0              3.0
# 4   2017-12-14 08:57:15        6   NaN      0        0.0              3.0
# 5   2017-12-14 08:57:16        6   NaN      0        0.0              3.0
# 6   2017-12-14 08:57:17        6   NaN      0        0.0              3.0
# 7   2017-12-14 08:57:18        6   NaN      0        0.0              3.0
# 8   2017-12-14 08:57:19        6   NaN      0        0.0              3.0
# 9   2017-12-14 08:57:20        6   NaN      0        0.0              3.0
# 10  2017-12-14 08:57:21        6   NaN      0        0.0              3.0
# 11  2017-12-14 08:57:22        6   NaN      0        0.0              3.0
# 12  2017-12-14 08:57:23        6   NaN      0        0.0              3.0
# 13  2017-12-14 08:57:24        6   NaN      0        0.0              3.0
# 14  2017-12-14 08:57:25        6   NaN      0        0.0              3.0
# 15  2017-12-14 08:57:26        6   NaN      0        0.0              3.0
# 16  2017-12-14 08:57:27        6   NaN      0        0.0              3.0
# 17  2017-12-14 08:57:28        6   NaN      0        0.0              3.0
# 18  2017-12-14 08:57:29        6   NaN      0        0.0              3.0
# 19  2017-12-14 08:57:30        6   NaN      0        0.0              3.0
# 20  2017-12-14 08:57:31        6   NaN      0        0.0              3.0
# 21  2017-12-14 08:57:32        6   NaN      0        0.0              3.0
# 22  2017-12-14 08:57:33        6   NaN      0        0.0              3.0
# 23  2017-12-14 08:57:34        6   NaN      0        0.0              3.0
# 24  2017-12-14 08:57:35        6   NaN      0        0.0              3.0
# 25  2017-12-14 08:57:36        6   NaN      0        0.0              3.0
# 26  2017-12-14 08:57:37        6   NaN      0        0.0              3.0
# 27  2017-12-14 08:57:38        6   NaN      0        0.0              3.0
# 28  2017-12-14 08:57:39        6   NaN      0        0.0              3.0
# 29  2017-12-14 08:57:40        6   NaN      0        0.0              3.0
# 30  2017-12-14 08:57:41        6   NaN      0        0.0              3.0
# 31  2017-12-14 08:57:42        6   NaN      0        0.0              3.0
# 32  2017-12-14 08:57:43        6   NaN      0        0.0              3.0
# 33  2017-12-14 08:57:44        6   NaN      0        0.0              3.0
# 34  2017-12-14 08:57:45        6   NaN      0        0.0              3.0
# 35  2017-12-14 08:57:46        6   NaN      0        0.0              3.0
# 36  2017-12-14 08:57:47        6   NaN      0        0.0              3.0
# 37  2017-12-14 08:57:48        6   NaN      0        0.0              3.0
# 38  2017-12-14 08:57:49        6   NaN      0        0.0              3.0
# 39  2017-12-14 08:57:50        6   NaN      0        0.0              3.0
# 40  2017-12-14 08:57:51        6   NaN      0        0.0              3.0
# 41  2017-12-14 08:57:52        6   NaN      0        0.0              3.0
# 42  2017-12-14 08:57:53        6   NaN      0        0.0              3.0
# 43  2017-12-14 08:57:54        6   NaN      0        0.0              3.0
# 44  2017-12-14 08:57:55        6   NaN      0        0.0              3.0
# 45  2017-12-14 08:57:56        6   NaN      0        0.0              3.0
# 46  2017-12-14 08:57:57        6   NaN      0        0.0              3.0
# 47  2017-12-14 08:57:58        6   NaN      0        0.0              3.0
# 48  2017-12-14 08:57:59        6   NaN      0        0.0              3.0
# 49  2017-12-14 08:58:00        6   NaN      0        0.0              3.0
# 50  2017-12-14 08:58:01        6   NaN      0        0.0              3.0
# 51  2017-12-14 08:58:02        6   NaN      0        0.0              3.0
# 52  2017-12-14 08:58:03        6   NaN      0        0.0              3.0
# 53  2017-12-14 08:58:04        6   NaN      0        0.0              3.0
# 54  2017-12-14 08:58:05        6   NaN      0        0.0              3.0
# 55  2017-12-14 08:58:06        6   NaN      0        0.0              3.0
# 56  2017-12-14 08:58:07        6   NaN      0        0.0              3.0
# 57  2017-12-14 08:58:08        6   NaN      0        0.0              3.0
# 58  2017-12-14 08:58:09        6   NaN      0        0.0              3.0
# 59  2017-12-14 08:58:10        6   NaN      0        0.0              3.0
# 60  2017-12-14 08:58:11        6   NaN      0        0.0              3.0
#
#     EMA_num_events  EMA_VAS  EMA_stress_type  Exam  Exam_stress  VF_task  \
# 0              NaN      0.0              NaN   NaN          NaN      NaN
# 1              NaN      0.0              NaN   NaN          NaN      NaN
# 2              NaN      0.0              NaN   NaN          NaN      NaN
# 3              NaN      0.0              NaN   NaN          NaN      NaN
# 4              NaN      0.0              NaN   NaN          NaN      NaN
# 5              NaN      0.0              NaN   NaN          NaN      NaN
# 6              NaN      0.0              NaN   NaN          NaN      NaN
# 7              NaN      0.0              NaN   NaN          NaN      NaN
# 8              NaN      0.0              NaN   NaN          NaN      NaN
# 9              NaN      0.0              NaN   NaN          NaN      NaN
# 10             NaN      0.0              NaN   NaN          NaN      NaN
# 11             NaN      0.0              NaN   NaN          NaN      NaN
# 12             NaN      0.0              NaN   NaN          NaN      NaN
# 13             NaN      0.0              NaN   NaN          NaN      NaN
# 14             NaN      0.0              NaN   NaN          NaN      NaN
# 15             NaN      0.0              NaN   NaN          NaN      NaN
# 16             NaN      0.0              NaN   NaN          NaN      NaN
# 17             NaN      0.0              NaN   NaN          NaN      NaN
# 18             NaN      0.0              NaN   NaN          NaN      NaN
# 19             NaN      0.0              NaN   NaN          NaN      NaN
# 20             NaN      0.0              NaN   NaN          NaN      NaN
# 21             NaN      0.0              NaN   NaN          NaN      NaN
# 22             NaN      0.0              NaN   NaN          NaN      NaN
# 23             NaN      0.0              NaN   NaN          NaN      NaN
# 24             NaN      0.0              NaN   NaN          NaN      NaN
# 25             NaN      0.0              NaN   NaN          NaN      NaN
# 26             NaN      0.0              NaN   NaN          NaN      NaN
# 27             NaN      0.0              NaN   NaN          NaN      NaN
# 28             NaN      0.0              NaN   NaN          NaN      NaN
# 29             NaN      0.0              NaN   NaN          NaN      NaN
# 30             NaN      0.0              NaN   NaN          NaN      NaN
# 31             NaN      0.0              NaN   NaN          NaN      NaN
# 32             NaN      0.0              NaN   NaN          NaN      NaN
# 33             NaN      0.0              NaN   NaN          NaN      NaN
# 34             NaN      0.0              NaN   NaN          NaN      NaN
# 35             NaN      0.0              NaN   NaN          NaN      NaN
# 36             NaN      0.0              NaN   NaN          NaN      NaN
# 37             NaN      0.0              NaN   NaN          NaN      NaN
# 38             NaN      0.0              NaN   NaN          NaN      NaN
# 39             NaN      0.0              NaN   NaN          NaN      NaN
# 40             NaN      0.0              NaN   NaN          NaN      NaN
# 41             NaN      0.0              NaN   NaN          NaN      NaN
# 42             NaN      0.0              NaN   NaN          NaN      NaN
# 43             NaN      0.0              NaN   NaN          NaN      NaN
# 44             NaN      0.0              NaN   NaN          NaN      NaN
# 45             NaN      0.0              NaN   NaN          NaN      NaN
# 46             NaN      0.0              NaN   NaN          NaN      NaN
# 47             NaN      0.0              NaN   NaN          NaN      NaN
# 48             NaN      0.0              NaN   NaN          NaN      NaN
# 49             NaN      0.0              NaN   NaN          NaN      NaN
# 50             NaN      0.0              NaN   NaN          NaN      NaN
# 51             NaN      0.0              NaN   NaN          NaN      NaN
# 52             NaN      0.0              NaN   NaN          NaN      NaN
# 53             NaN      0.0              NaN   NaN          NaN      NaN
# 54             NaN      0.0              NaN   NaN          NaN      NaN
# 55             NaN      0.0              NaN   NaN          NaN      NaN
# 56             NaN      0.0              NaN   NaN          NaN      NaN
# 57             NaN      0.0              NaN   NaN          NaN      NaN
# 58             NaN      0.0              NaN   NaN          NaN      NaN
# 59             NaN      0.0              NaN   NaN          NaN      NaN
# 60             NaN      0.0              NaN   NaN          NaN      NaN
#
#     Math_task  Technical_issue
# 0         NaN              NaN
# 1         NaN              NaN
# 2         NaN              NaN
# 3         NaN              NaN
# 4         NaN              NaN
# 5         NaN              NaN
# 6         NaN              NaN
# 7         NaN              NaN
# 8         NaN              NaN
# 9         NaN              NaN
# 10        NaN              NaN
# 11        NaN              NaN
# 12        NaN              NaN
# 13        NaN              NaN
# 14        NaN              NaN
# 15        NaN              NaN
# 16        NaN              NaN
# 17        NaN              NaN
# 18        NaN              NaN
# 19        NaN              NaN
# 20        NaN              NaN
# 21        NaN              NaN
# 22        NaN              NaN
# 23        NaN              NaN
# 24        NaN              NaN
# 25        NaN              NaN
# 26        NaN              NaN
# 27        NaN              NaN
# 28        NaN              NaN
# 29        NaN              NaN
# 30        NaN              NaN
# 31        NaN              NaN
# 32        NaN              NaN
# 33        NaN              NaN
# 34        NaN              NaN
# 35        NaN              NaN
# 36        NaN              NaN
# 37        NaN              NaN
# 38        NaN              NaN
# 39        NaN              NaN
# 40        NaN              NaN
# 41        NaN              NaN
# 42        NaN              NaN
# 43        NaN              NaN
# 44        NaN              NaN
# 45        NaN              NaN
# 46        NaN              NaN
# 47        NaN              NaN
# 48        NaN              NaN
# 49        NaN              NaN
# 50        NaN              NaN
# 51        NaN              NaN
# 52        NaN              NaN
# 53        NaN              NaN
# 54        NaN              NaN
# 55        NaN              NaN
# 56        NaN              NaN
# 57        NaN              NaN
# 58        NaN              NaN
# 59        NaN              NaN
# 60        NaN              NaN

# %%
s=np.unique(fitbit.Subject)
print( s, len(s) )
# Out:
# [ 6 16 17 20 22 32 34 43 46 52 57 58 60 61 62 64 69 71] 18

# %%
import numpy as np
      
q=np.where( fitbit['Subject']== 6 )[0]         
fb_hr = fitbit.iloc[ q, fitbit.columns.get_loc( 'HR' ) ].values
fb_steps = fitbit.iloc[ q, fitbit.columns.get_loc( 'Steps' ) ].values
fb_elevation = fitbit.iloc[ q, fitbit.columns.get_loc( 'Elevation' ) ].values

import matplotlib.pyplot as plt

from IPython.display import Javascript
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 14821})'''))


H=24
W=12
plt.clf();

fig,axes=plt.subplots(2,1, figsize=( H, W ))

a=0
axes[a].plot(fb_steps, label='Steps')
axes[a].plot(fb_hr, label='Heart rate')
axes[a].legend();
a=1
axes[a].plot(fb_elevation, label='Elevation')
axes[a].set_xlabel('Seconds');

# %%
q=np.where( fitbit['Subject']== 46 )[0]         
fb_hr = fitbit.iloc[ q, fitbit.columns.get_loc( 'HR' ) ].values
fb_steps = fitbit.iloc[ q, fitbit.columns.get_loc( 'Steps' ) ].values
fb_elevation = fitbit.iloc[ q, fitbit.columns.get_loc( 'Elevation' ) ].values

import matplotlib.pyplot as plt

from IPython.display import Javascript
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 14821})'''))


H=24
W=12
plt.clf();

fig,axes=plt.subplots(2,1, figsize=( H, W ))

a=0
axes[a].plot(fb_steps, label='Steps')
axes[a].plot(fb_hr, label='Heart rate')
axes[a].legend();
a=1
axes[a].plot(fb_elevation, label='Elevation')
axes[a].set_xlabel('Seconds');

# %%
q=np.where( fitbit['Subject']== 71 )[0]         
fb_hr = fitbit.iloc[ q, fitbit.columns.get_loc( 'HR' ) ].values
fb_steps = fitbit.iloc[ q, fitbit.columns.get_loc( 'Steps' ) ].values
fb_elevation = fitbit.iloc[ q, fitbit.columns.get_loc( 'Elevation' ) ].values

import matplotlib.pyplot as plt

from IPython.display import Javascript
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 14821})'''))


H=24
W=12
plt.clf();

fig,axes=plt.subplots(2,1, figsize=( H, W ))

a=0
axes[a].plot(fb_steps, label='Steps')
axes[a].plot(fb_hr, label='Heart rate')
axes[a].legend();
a=1
axes[a].plot(fb_elevation, label='Elevation')
axes[a].set_xlabel('Seconds');
